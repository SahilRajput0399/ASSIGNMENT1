# %% [markdown]
# Ques1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Ans. Matplotlib is a data visualization library for creating static, animated, and interactive visualizations in Python. It is a powerful tool for creating various types of plots, charts, and graphs, and is widely used in the scientific and data analysis communities.
#
# Matplotlib is used to create visualizations that help to understand data, communicate insights, and support decision-making. It provides a wide range of customization options, allowing users to create high-quality visualizations tailored to their specific needs.
#
# The Pyplot module of Matplotlib is a collection of functions that provide a simple and intuitive interface for creating various types of plots. Some of the commonly used plots that can be created using Pyplot are:
#
# 1.Line plot
# 2.Scatter plot
# 3.Histogram
# 4.Bar chart
# 5.Pie chart

# %% [markdown]
# Ques2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Ans.  A scatter plot is a type of plot that displays values for two variables as points on a two-dimensional coordinate system. Each point represents an observation, and the position of the point on the x and y-axis represents the values of the two variables.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3) 
x = 3 + np.random.normal(0,2,50)   
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('The Scatter Plot Graph')
plt.show()

# %% [markdown]
# Ques3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# Ans. The subplot() function is used to create multiple plots in the same figure. It allows you to create a grid of plots and specify where each plot should be placed in the grid. The syntax for subplot() function is as follows:
#
# plt.subplot(num_rows, num_cols, plot_num)

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np. array([0,100,200,300,400,500])

x2 = np.array([0,1,2,3,4,5])
y2 = np.array([50,20,40,20,60,70])

x3 = np.array([0,1,2,3,4,5])
y3 = np.array([10,20,30,40,50,60])

x4 = np.array([0,1,2,3,4,5])
y4 = np.array([200,350,250,550,450,150])

plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title('Line 1')

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title('Line 2')

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title('Line 3')

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title('Line 4')

plt.suptitle('Four Line Plots')

plt.show()

# %% [markdown]
# Ques4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Ans. A bar plot is a way of representing data using rectangular bars. It is used to compare and visualize the quantities or values of different categories or groups in a dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
plt.xlabel('companies')
plt.ylabel('Profits')
plt.title('COMPANY PROFITS')
plt.show()

# %%
plt.barh(company,profit)
plt.xlabel('companies')
plt.ylabel('Profits')
plt.title('COMPANY PROFITS')
plt.show()

# %% [markdown]
# Ques5. What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Ans. A box plot, also known as a box is a graphical representation of a dataset that displays the distribution of the data through five key summary statistics: minimum, first quartile (Q1), median, third quartile (Q3), and maximum.
#
# Box plots are used to provide a visual summary of the distribution of a dataset and to identify potential outliers. They are commonly used in data analysis and statistics, particularly in fields such as finance, economics, and social sciences.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

fig = plt.figure()

a = fig.add_subplot()
a.boxplot([box1,box2])

a.set_title('Box Plot Example')


plt.show()
